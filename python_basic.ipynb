# %% [markdown]
# <a href="https://colab.research.google.com/github/nareswaricarissaaviva/data_science_w1/blob/main/python_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Data science")
# Out:
# Welcome to Data science

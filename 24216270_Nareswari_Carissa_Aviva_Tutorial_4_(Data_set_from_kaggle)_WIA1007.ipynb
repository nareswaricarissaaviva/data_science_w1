# %% [markdown]
# <a href="https://colab.research.google.com/github/nareswaricarissaaviva/data_science_w1/blob/main/24216270_Nareswari_Carissa_Aviva_Tutorial_4_(Data_set_from_kaggle)_WIA1007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7ce0c476-9c57-4ece-89e4-ac6706d7864e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ce0c476-9c57-4ece-89e4-ac6706d7864e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d arunjangir245/irisraw
# Out:
# Dataset URL: https://www.kaggle.com/datasets/arunjangir245/irisraw
# License(s): DbCL-1.0
# ...
#   0% 0.00/0.99k [00:00<?, ?B/s]
# 100% 0.99k/0.99k [00:00<00:00, 3.40MB/s]

# %%
# !unzip irisraw.zip
# Out:
# Archive:  irisraw.zip
#   inflating: irisraw.csv

# %%
import pandas as pd
df = pd.read_csv("irisraw.csv")
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import pandas as pd
df = pd.read_csv("irisraw.csv")  # ganti sesuai nama file
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df
# Out:
#      sepal length  sepal width  petal length  petal width          species
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
#2.Evaluate if the data is good or not. Does it have enough samples?
# Check the shape
print("Dataset shape:", df.shape)  # (rows, columns)

# Info about types and non-null counts
print(df.info())

# Basic statistics
print(df.describe())
# Out:
# Dataset shape: (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# ...

# %%
#3.How many features does it have? Is it enough?
print("Features:", df.columns[:-1].tolist())
print("Number of features:", len(df.columns) - 1)
# Out:
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Number of features: 4

# %%
#4.How many samples/observation does it have? Is it enough?
print("Number of samples:", df.shape[0])
# Out:
# Number of samples: 150

# %%
#5.What are the datatypes does the dataset consist of?
print(df.dtypes)
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object

# %%
#6. # Count missing values per column
print("Null values per column:")
print(df.isnull().sum())
# Out:
# Null values per column:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
#7. Which column is the feature, which is the target output?
features = df.columns[:-1].tolist()
print("Feature columns:", features)

target = 'target'
print("Target column:", target)
# Out:
# Feature columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target column: target

# %%
#8. Does it have missing values? If yes, which column, which row.
# Show rows with any missing values
print("Rows with missing values:")
print(df[df.isnull().any(axis=1)])
# Out:
# Rows with missing values:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), target]
# Index: []
